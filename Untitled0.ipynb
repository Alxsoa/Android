# %% [markdown]
# <a href="https://colab.research.google.com/github/Alxsoa/Android/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
#
#######################################################################
# Inclusao de Modulos Necessarios 
#######################################################################
#
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DadosCandidatoEleicao2020 = pd.read_csv( '/content/drive/My Drive/bweb_1t_RS_181120201549.csv', sep = ';', encoding = 'iso-8859-1')
DadosCandidatoEleicao2020.head()
# Out:
#    DT_GERACAO HH_GERACAO  ...  NR_JUNTA_APURADORA  NR_TURMA_APURADORA
# 0  18/11/2020   15:49:53  ...                -1.0                -1.0
# 1  18/11/2020   15:49:53  ...                -1.0                -1.0
# 2  18/11/2020   15:49:53  ...                -1.0                -1.0
# 3  18/11/2020   15:49:53  ...                -1.0                -1.0
# 4  18/11/2020   15:49:53  ...                -1.0                -1.0
#
# [5 rows x 45 columns]
